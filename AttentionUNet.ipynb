# %%
import h5py
import numpy as np
import PIL
import PIL.Image as pil
from sklearn.model_selection import train_test_split
import cv2
from tqdm import tqdm


from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle

from Pathology import *
import matplotlib.pyplot as plt
import torchvision.transforms as transforms

gray_white_list = [0, 2, 4, 5, 6, 9, 10, 12, 13, 14, 16, 17, 18, 19, 20, 21, 22, 23, 24, 26, 27, 28, 29]
white_gray_list = [1, 3, 7, 8, 11, 15, 25]
empty = [8]
corrupted = [15]

# %%
import tensorflow as tf

from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau, CSVLogger, EarlyStopping
import h5py
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, ZeroPadding2D, UpSampling2D, Dense, concatenate, Conv2DTranspose

from tensorflow.keras.layers import MaxPooling2D, GlobalAveragePooling2D, MaxPooling2D, Dense, Dropout, Activation
# from tensorflow.keras.layers.core import Dense, Dropout, Activation
from tensorflow.keras.layers import BatchNormalization, Dropout, Flatten, Lambda, ELU, LeakyReLU, GaussianDropout
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.regularizers import l2
# from tensorflow.keras.layers.noise import GaussianDropout
from tensorflow.keras.models import Model

from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten
from keras.layers import Activation
from keras.models import Sequential, Model
from keras.optimizers import Adam

from datetime import datetime
from tensorflow.keras.metrics import MeanIoU
import cv2
import os
from matplotlib import pyplot as plt
from tensorflow.keras.utils import normalize
from tensorflow.keras import backend as K

# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau, CSVLogger, EarlyStopping
import h5py
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, ZeroPadding2D, UpSampling2D, Dense, concatenate, Conv2DTranspose

from tensorflow.keras.layers import MaxPooling2D, GlobalAveragePooling2D, MaxPooling2D, Dense, Dropout, Activation
# from tensorflow.keras.layers.core import Dense, Dropout, Activation
from tensorflow.keras.layers import BatchNormalization, Dropout, Flatten, Lambda, ELU, LeakyReLU, GaussianDropout
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.regularizers import l2
# from tensorflow.keras.layers.noise import GaussianDropout
from tensorflow.keras.models import Model

from datetime import datetime
from tensorflow.keras.metrics import MeanIoU
import cv2
import os
from matplotlib import pyplot as plt
from tensorflow.keras.utils import normalize
from tensorflow.keras import backend as K


from PIL import Image
from Model import UNet1, UNet2, UNet3, UNetPlus1, UNetPlusPlus1, UNetTest, Attention_ResUNet
from Util import getDatarange, prepareData, showResults, getDatarange_multiclass, multi_class_preparation

# %%
from __future__ import print_function, division
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data
import torch

# %%
tf.test.is_gpu_available(cuda_only=False, min_cuda_compute_capability=None)
# Out:
# WARNING:tensorflow:From C:\Users\Mdsp\AppData\Local\Temp\ipykernel_15684\565982385.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %%
def getDatarange(hdf5File,startpat,endpat,aug=False, rows=128, cols=128):
    X = []
    Y = []
    patient_folders = list(hdf5File.keys())
    for pat in tqdm(range(startpat,endpat)):
        if pat == 15 or pat == 8:
            continue
        patient = patient_folders[pat]
        print(str(patient))
        
        Lung = hdf5File.get(str(patient) + '/LUNG')
        Mask = hdf5File.get(str(patient) + '/MASK')
        Lung_items = list(Lung.items())
        Mask_items = list(Mask.items())
        for i in tqdm(range(len(Mask_items)),desc='images'):
            Lung_img_name = Lung_items[i][1]
            Mask_img_name = Mask_items[i][1]
            Lung_imgs = np.array(Lung_img_name)
            Mask_imgs = np.array(Mask_img_name)

            if pat in white_gray_list:
                left_idxs = np.where(Mask_imgs==200)
                right_idxs = np.where(Mask_imgs==100)
                Mask_imgs[left_idxs] = 100
                Mask_imgs[right_idxs] = 200

            if Lung_imgs.shape != (rows,cols):
                Lung_ima = cv2.resize(Lung_imgs,(rows,cols))
            if Mask_imgs.shape != (rows,cols):
                Mask_ima = cv2.resize(Mask_imgs,(rows,cols))
            ret,thresh=cv2.threshold(Mask_ima,2,255,cv2.THRESH_BINARY)
            X.append(Lung_ima)
            Y.append(thresh)
    return np.array(X), np.array(Y)

# %%
def getPolygonDatarange(hdf5File,startpat,endpat,aug=False, rows=128, cols=128):
    X = []
    Y = []
    patient_folders = list(hdf5File.keys())
    for pat in tqdm(range(startpat,endpat)):
        if pat == 15 or pat == 8:
            continue
        patient = patient_folders[pat]
        print(str(patient))

        Lung = hdf5File.get(str(patient) + '/LUNG')
        Mask = hdf5File.get(str(patient) + '/MASK')
        Lung_items = list(Lung.items())
        Mask_items = list(Mask.items())
        for i in tqdm(range(len(Mask_items)),desc='images'):
            Lung_img_name = Lung_items[i][1]
            Mask_img_name = Mask_items[i][1]
            Lung_imgs = np.array(Lung_img_name)
            Mask_imgs = np.array(Mask_img_name)

            if pat in white_gray_list:
                left_idxs = np.where(Mask_imgs==200)
                right_idxs = np.where(Mask_imgs==100)
                Mask_imgs[left_idxs] = 100
                Mask_imgs[right_idxs] = 200

            if Lung_imgs.shape != (rows,cols):
                Lung_ima = cv2.resize(Lung_imgs,(rows,cols))
            if Mask_imgs.shape != (rows,cols):
                Mask_ima = cv2.resize(Mask_imgs,(rows,cols))
            ret,thresh=cv2.threshold(Mask_ima,2,255,cv2.THRESH_BINARY)
            
            
            if aug==True:
                proba = random.uniform(0, 1)
                items = [(70,150),(100,200),(150,230),(200,240)]
                patients = random.choice(items)
                plt.imshow(Mask_ima, cmap='gray')
                ret,thresh = cv2.threshold(Mask_ima,2,255,cv2.THRESH_BINARY)
                if (proba > 0.5):
                    # replace the image with the Fake Generated Polygon
                    radius = random.randrange(5,15)
                    vertices = random.randrange(30,60)
                    contours, _= cv2.findContours(thresh, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
                    print(len(contours))
                    if(len(contours) > 0):
                        l = int(contours[0].size / 2)
                        if l > 0:
                            idx = random.randrange(0,l)
                            center = tuple(tuple(contours[0][idx])[0])
                        else:
                            center = (60,60)
                    else:
                        center = (60,60)
                    for i in range(2) :
                        Fake_Lung_imgs = createPolygonFakeImage(Lung_ima, thresh,patients[0],patients[1], 
                                        img_rows=rows, img_cols=cols, avg_radius = radius, num_vertices = vertices, center = center)
                        if i > 1:
                            sig = (i -1)*0.5
                            img = cv2.GaussianBlur(Fake_Lung_imgs,(5,5),sig)
                            Fake_Lung_imgs = img
                        X.append(Fake_Lung_imgs)
                        Y.append(thresh)
                else:
                    # keep the same image                   
                    X.append(Lung_ima)
                    Y.append(thresh)
            else:
                X.append(Lung_ima)
                Y.append(thresh)
    return np.array(X), np.array(Y)

# %%
hdf5File = h5py.File('C:\\Users\\Mdsp\\Desktop\\Catalin project\\hdf5_data_2.h5', 'r')

# %%
X, Y = getDatarange(hdf5File,0,30)
# Out:
#   0%|                                                                                           | 0/30 [00:00<?, ?it/s]
# images:  49%|██████████████████████████████████▊                                    | 278/568 [00:01<00:01, 243.62it/s]
# images:  53%|█████████████████████████████████████▉                                 | 303/568 [00:01<00:01, 244.30it/s]
# images:  58%|█████████████████████████████████████████▏                             | 329/568 [00:01<00:00, 247.26it/s]
# images:  62%|████████████████████████████████████████████▏                          | 354/568 [00:01<00:00, 228.89it/s]
# images:  67%|███████████████████████████████████████████████▌                       | 380/568 [00:01<00:00, 237.50it/s]
# images:  71%|██████████████████████████████████████████████████▊                    | 406/568 [00:01<00:00, 243.43it/s]
# images:  76%|█████████████████████████████████████████████████████▉                 | 431/568 [00:01<00:00, 242.50it/s]
# images:  81%|█████████████████████████████████████████████████████████▌             | 460/568 [00:01<00:00, 254.52it/s]
# images:  86%|█████████████████████████████████████████████████████████████▏         | 489/568 [00:01<00:00, 262.63it/s]
# images:  91%|████████████████████████████████████████████████████████████████▊      | 518/568 [00:02<00:00, 269.60it/s]
# images: 100%|███████████████████████████████████████████████████████████████████████| 568/568 [00:02<00:00, 262.20it/s]
#  87%|███████████████████████████████████████████████████████████████████████           | 26/30 [00:28<00:05,  1.33s/it]
# Gaiji
# images:   0%|                                                                                  | 0/416 [00:00<?, ?it/s]
# images:  12%|████████▋                                                               | 50/416 [00:00<00:00, 493.93it/s]
# images:  24%|█████████████████                                                      | 100/416 [00:00<00:00, 460.75it/s]
# images:  37%|██████████████████████████                                             | 153/416 [00:00<00:00, 489.64it/s]
# images:  49%|██████████████████████████████████▋                                    | 203/416 [00:00<00:00, 491.77it/s]
# images:  61%|███████████████████████████████████████████▏                           | 253/416 [00:00<00:00, 485.02it/s]
# images:  73%|███████████████████████████████████████████████████▌                   | 302/416 [00:00<00:00, 461.82it/s]
# images:  84%|███████████████████████████████████████████████████████████▌           | 349/416 [00:00<00:00, 436.46it/s]
# images: 100%|███████████████████████████████████████████████████████████████████████| 416/416 [00:00<00:00, 475.46it/s]
#  90%|█████████████████████████████████████████████████████████████████████████▊        | 27/30 [00:29<00:03,  1.25s/it]
# Gallier
# images:   0%|                                                                                  | 0/327 [00:00<?, ?it/s]
# images:  34%|███████████████████████▊                                              | 111/327 [00:00<00:00, 1106.62it/s]
# images: 100%|██████████████████████████████████████████████████████████████████████| 327/327 [00:00<00:00, 1053.15it/s]
#  93%|████████████████████████████████████████████████████████████████████████████▌     | 28/30 [00:29<00:02,  1.01s/it]
# Gerbaux
# images:   0%|                                                                                  | 0/308 [00:00<?, ?it/s]
# images:  32%|███████████████████████▏                                                | 99/308 [00:00<00:00, 977.58it/s]
# images:  64%|█████████████████████████████████████████████▍                         | 197/308 [00:00<00:00, 966.17it/s]
# images: 100%|███████████████████████████████████████████████████████████████████████| 308/308 [00:00<00:00, 974.07it/s]
#  97%|███████████████████████████████████████████████████████████████████████████████▎  | 29/30 [00:30<00:00,  1.19it/s]
# Ghiles
# images:   0%|                                                                                  | 0/321 [00:00<?, ?it/s]
# images:  29%|█████████████████████                                                   | 94/321 [00:00<00:00, 935.47it/s]
# images:  59%|█████████████████████████████████████████▌                             | 188/321 [00:00<00:00, 904.98it/s]
# images: 100%|███████████████████████████████████████████████████████████████████████| 321/321 [00:00<00:00, 698.92it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:30<00:00,  1.03s/it]

# %%
from matplotlib import pyplot as plt
plt.imshow(X[100], cmap='gray')
plt.show()

# %%
Lung_ima = X[100]
thresh = Y[100]

# %%
binary_map = (thresh > 0).astype(np.uint8)
connectivity = 8 # or whatever you prefer
num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(binary_map, connectivity, cv2.CV_32S)

# %%
contours, _= cv2.findContours(thresh, cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# %%
# idx = random.randrange(0,contours[0].size / 2 - 1)
# Fake_Lung_imgs = createPolygonFakeImage(Lung_ima, thresh,200,240, img_rows=128, img_cols=128, center = tuple(tuple(contours[0][idx])[0]), avg_radius = 7, num_vertices = 100)
# sig = 0.5
# img = cv2.GaussianBlur(Fake_Lung_imgs,(5,5),sig)
# Fake_Lung_imgs = img

# %%
# plt.imshow(Fake_Lung_imgs, cmap='gray')
# plt.show()

# %%
img_size = 128
a_degrees = 12
a_distortion_scale = 0.2
a_scale = (0.8, 1.2)
a_translate = (0.133, 0.133)
a_jitter = [0.3, 0.3, 0.3, 0.3]
a_padding_ratio = 0.067

# %%
def show_classic_aug(image):
    img_aug, names = [], []
    image = transforms.ToPILImage()(image)
    img_aug.append(image)
    names.append("Original-Image")
    img_aug.append(transforms.RandomRotation(degrees=(-a_degrees, a_degrees))(image))
    names.append("RandomRotation")
    img_aug.append(transforms.RandomHorizontalFlip(p=1)(image))
    names.append("RandomHorizontalFlip")
    img_aug.append(transforms.RandomPerspective(distortion_scale=a_distortion_scale, p=0.5)(image))
    names.append("RandomPerspective")
    img_aug.append(transforms.RandomAffine(degrees=0, scale=a_scale)(image))
    names.append("RandomAffine-Scale")
    img_aug.append(transforms.RandomAffine(degrees=0, translate=a_translate)(image))
    names.append("RandomAffine-Translate")
    img_aug.append(transforms.ColorJitter(brightness=a_jitter[0], 
                                          contrast=a_jitter[1], 
                                          saturation=a_jitter[2], 
                                          hue=a_jitter[3])(image))
    names.append("ColorJitter")
    img_aug.append(transforms.Pad(padding=round(a_padding_ratio * img_size),
                                  fill=0,
                                  padding_mode='symmetric')(image))
    names.append("Pad")
    plt.figure(figsize=(20, 10))
    for i in range(8):
        plt.subplot(2, 4, i + 1)
        plt.imshow(img_aug[i], cmap = 'gray')
        plt.title(names[i])
    plt.show()

# %%
show_classic_aug(Lung_ima)

# %%
def save_classic_aug(image, path):
    try:
        image = image.convert('grayscale')
        image.save(path)
    except (ValueError, KeyError, OSError) as err:
        print(err)
        return None

# %%
from tensorflow.python.client import device_lib
def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos]
print(get_available_devices())
# Out:
# ['/device:CPU:0']

# %%
img_rows = 128
img_cols = 128
channels = 1
img_shape = (img_rows, img_cols, channels)

z_dim = 100

# %%
def generator(img_shape, z_dim):
    
    model = Sequential()
    
    # Hidden layer
    model.add(Dense(128, input_dim=z_dim))

    # Leaky ReLU
    model.add(LeakyReLU(alpha=0.01))

    # Output layer with tanh activation
    model.add(Dense(128*128*1, activation='tanh'))
    model.add(Reshape(img_shape))

    z = Input(shape=(z_dim,))
    img = model(z)

    return Model(z, img)

# %%
def discriminator(img_shape):
    
    model = Sequential()

    model.add(Flatten(input_shape=img_shape))

    # Hidden layer
    model.add(Dense(128))

    # Leaky ReLU
    model.add(LeakyReLU(alpha=0.01))
    # Output layer with sigmoid activation
    model.add(Dense(1, activation='sigmoid'))

    img = Input(shape=img_shape)
    prediction = model(img)

    return Model(img, prediction)

# %%
discriminator = discriminator(img_shape)
discriminator.compile(loss='binary_crossentropy', 
                      optimizer=Adam(), metrics=['accuracy'])

# Build the Generator
generator = generator(img_shape, z_dim)

# Generated image to be used as input
z = Input(shape=(100,))
img = generator(z)

# Keep Discriminator’s parameters constant during Generator training
discriminator.trainable = False

# The Discriminator’s prediction
prediction = discriminator(img)

# Combined GAN model to train the Generator
combined = Model(z, prediction)
combined.compile(loss='binary_crossentropy', optimizer=Adam())

# %%
losses = []
accuracies = []

def train(iterations, batch_size, sample_interval):
    
    data_slice = 20
    X_train = X[0:8000,:]
    #X_train = X[:data_slice,:]
    # Rescale -1 to 1
    #X_train = X_train / 127.5 - 1.
    X_train = np.expand_dims(X_train, axis=3)
    

    # Labels for real and fake examples
    real = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))

    for iteration in range(iterations):
        
        # -------------------------
        #  Train the Discriminator
        # -------------------------

        # Select a random batch of real images
        idx = np.random.randint(0, X_train.shape[0], batch_size)
        imgs = X_train[idx]

        # Generate a batch of fake images
        z = np.random.normal(0, 1, (batch_size, 100))
        gen_imgs = generator.predict(z)

        # Discriminator loss
        d_loss_real = discriminator.train_on_batch(imgs, real)
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
        
        z = np.random.normal(0, 1, (batch_size, 100))
        gen_imgs = generator.predict(z)

        # Generator loss
        g_loss = combined.train_on_batch(z, real)

        if iteration % sample_interval == 0:
            
            # Output training progress
            print ("%d [D loss: %f, acc.: %.2f%%] [G loss: %f]" % 
                         (iteration, d_loss[0], 100*d_loss[1], g_loss))
            
            # Save losses and accuracies so they can be plotted after training
            losses.append((d_loss[0], g_loss))
            accuracies.append(100*d_loss[1])

            # Output generated image samples 
            sample_image(iteration)

# %%
def sample_image(iteration):


    # Sample random noise
    z = np.random.normal(0, 1, 
              (1, z_dim))

    # Generate images from random noise 
    gen_imgs = generator.predict(z)

    # Rescale images to 0-1
    gen_imgs = 0.5 * gen_imgs + 0.5

    plt.imshow(gen_imgs[0, :,:,0], cmap = 'gray')

# %%
import warnings; warnings.simplefilter('ignore')

# %%
# iterations = 1000
# batch_size = 32
# sample_interval = 100

# # Train the GAN for the specified number of iterations
# train(iterations, batch_size, sample_interval)

# #number of images: 10,798

# %%
output_path_single_class = "C:\\Users\\Mdsp\\Desktop\\Catalin project\\LungImageSegmentation-main\\output\\single_class\\"
output_path_multi_class = "C:\\Users\\Mdsp\\Desktop\\Catalin project\\LungImageSegmentation-main\\output\\multi_class\\"
preprocessing_output = "preprocessing\\"
evaluation_output = "evaluations\\"

# %%
def train_single_class(batch_size=8, start=0, end=30, n_classes=1, img_rows=128, img_cols=128):
    model = Attention_ResUNet()
    model.compile(optimizer=Adam(lr=1e-4), loss='binary_crossentropy', metrics=['accuracy']) 
    model.summary()
    X, Y = getDatarange(hdf5File,start,end,aug=True, rows=img_rows, cols=img_cols)
    print(X.shape, Y.shape)
    Xnew = []
    Ynew = []
    for i in range(len(Y)):
        if cv2.countNonZero(Y[i]) != 0:
            
            Xnew.append(X[i])
            Ynew.append(Y[i])
    X = np.array(Xnew)
    Y = np.array(Ynew)
    print(X.shape, Y.shape)
    
    preprocessing_idxs = np.random.choice(X.shape[0], 9, replace=False)
    for i in range(preprocessing_idxs.shape[0]):
        cv2.imwrite(os.path.join(output_path_single_class+preprocessing_output, "Xpreprocessing_sample_stage_1_" + str(i) + ".jpeg"), X[preprocessing_idxs[i]])
        cv2.imwrite(os.path.join(output_path_single_class+preprocessing_output, "Ypreprocessing_sample_stage_1_" + str(i) + ".jpeg"), Y[preprocessing_idxs[i]])   

    trainX1, evalX, trainY1, evalY = train_test_split(X, Y, test_size=0.05, shuffle=True)
    trainX, valX, trainY, valY = train_test_split(trainX1, trainY1, test_size=0.2, shuffle=True)

    print("Train set size : ", len(trainX))
    print("Validation set size : ", len(valX))
    print("Total images : ", len(X))

    trainX, trainY, valX, valY = prepareData(trainX, trainY, valX, valY)
    print(trainX.shape)
    print(valX.shape)
    csv_logger = CSVLogger('train'+str('')+'.log', append=True, separator=';')
    earlystopping = EarlyStopping(monitor='accuracy', verbose=1, min_delta=0.005, patience=3, mode='max')
    callbacks_list = [csv_logger, earlystopping]

    history = model.fit(trainX, trainY, epochs=6, batch_size=batch_size, verbose=1, validation_data=(valX, valY),callbacks=callbacks_list)

    model.save('model'+str('_single_class')+ str('AttentionNet') +'.hdf5')
    showResults(history)
    return model

# %%
def train(batch_size=32, start=0, end=30, n_classes=1, img_rows=128, img_cols=128):
    if n_classes == 1:
        return train_single_class(batch_size=batch_size, start=start, end=end, n_classes=1, img_rows=img_rows, img_cols=img_cols)
    else:
        return train_multiclass(batch_size=batch_size, start=start, end=end, n_classes=n_classes, img_rows=img_rows, img_cols=img_cols)

# %%
train()
# Out:
# Model: "AttentionResUNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d_96 (Conv2D)             (None, 128, 128, 32  320         ['input_6[0][0]']
#                                 )
#
#  batch_normalization_72 (BatchN  (None, 128, 128, 32  128        ['conv2d_96[0][0]']
#  ormalization)                  )
#
#  activation_60 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_72[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 128, 128, 32  9248        ['activation_60[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 128, 128, 32  64          ['input_6[0][0]']
#                                 )
#
#  batch_normalization_73 (BatchN  (None, 128, 128, 32  128        ['conv2d_97[0][0]']
#  ormalization)                  )
#
#  batch_normalization_74 (BatchN  (None, 128, 128, 32  128        ['conv2d_98[0][0]']
#  ormalization)                  )
#
#  activation_61 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_73[0][0]']
#                                 )
#
#  add_26 (Add)                   (None, 128, 128, 32  0           ['batch_normalization_74[0][0]',
#                                 )                                 'activation_61[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 64, 64, 32)  0           ['add_26[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 64, 64, 64)   18496       ['max_pooling2d_8[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 64, 64, 64)  256         ['conv2d_99[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_75[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 64, 64, 64)   36928       ['activation_62[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 64, 64, 64)   2112        ['max_pooling2d_8[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 64, 64, 64)  256         ['conv2d_100[0][0]']
#  ormalization)
#
#  batch_normalization_77 (BatchN  (None, 64, 64, 64)  256         ['conv2d_101[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_76[0][0]']
#
#  add_27 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_77[0][0]',
#                                                                   'activation_63[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 64)  0           ['add_27[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 32, 32, 128)  73856       ['max_pooling2d_9[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 32, 32, 128)  512        ['conv2d_102[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_78[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 32, 32, 128)  147584      ['activation_64[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 32, 32, 128)  8320        ['max_pooling2d_9[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 32, 32, 128)  512        ['conv2d_103[0][0]']
#  ormalization)
#
#  batch_normalization_80 (BatchN  (None, 32, 32, 128)  512        ['conv2d_104[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_79[0][0]']
#
#  add_28 (Add)                   (None, 32, 32, 128)  0           ['batch_normalization_80[0][0]',
#                                                                   'activation_65[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 16, 16, 128)  0          ['add_28[0][0]']
#  )
#
#  conv2d_105 (Conv2D)            (None, 16, 16, 256)  295168      ['max_pooling2d_10[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_105[0][0]']
#  ormalization)
#
#  activation_66 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_81[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 16, 16, 256)  590080      ['activation_66[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 16, 16, 256)  33024       ['max_pooling2d_10[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_106[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_107[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_82[0][0]']
#
#  add_29 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_83[0][0]',
#                                                                   'activation_67[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 8, 8, 256)   0           ['add_29[0][0]']
#  )
#
#  conv2d_108 (Conv2D)            (None, 8, 8, 512)    1180160     ['max_pooling2d_11[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_108[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_84[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 8, 8, 512)    2359808     ['activation_68[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 8, 8, 512)    131584      ['max_pooling2d_11[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_109[0][0]']
#  ormalization)
#
#  batch_normalization_86 (BatchN  (None, 8, 8, 512)   2048        ['conv2d_110[0][0]']
#  ormalization)
#
#  activation_69 (Activation)     (None, 8, 8, 512)    0           ['batch_normalization_85[0][0]']
#
#  add_30 (Add)                   (None, 8, 8, 512)    0           ['batch_normalization_86[0][0]',
#                                                                   'activation_69[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 8, 8, 256)    131328      ['add_30[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_111[0][0]']
#  ormalization)
#
#  activation_70 (Activation)     (None, 8, 8, 256)    0           ['batch_normalization_87[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 8, 8, 256)    65792       ['activation_70[0][0]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 8, 8, 256)   590080      ['conv2d_113[0][0]']
#  spose)
#
#  conv2d_112 (Conv2D)            (None, 8, 8, 256)    262400      ['add_29[0][0]']
#
#  add_31 (Add)                   (None, 8, 8, 256)    0           ['conv2d_transpose_8[0][0]',
#                                                                   'conv2d_112[0][0]']
#
#  activation_71 (Activation)     (None, 8, 8, 256)    0           ['add_31[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 8, 8, 1)      257         ['activation_71[0][0]']
#
#  activation_72 (Activation)     (None, 8, 8, 1)      0           ['conv2d_114[0][0]']
#
#  up_sampling2d_16 (UpSampling2D  (None, 16, 16, 1)   0           ['activation_72[0][0]']
#  )
#
#  lambda_8 (Lambda)              (None, 16, 16, 256)  0           ['up_sampling2d_16[0][0]']
#
#  multiply_8 (Multiply)          (None, 16, 16, 256)  0           ['lambda_8[0][0]',
#                                                                   'add_29[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 16, 16, 256)  65792       ['multiply_8[0][0]']
#
#  up_sampling2d_17 (UpSampling2D  (None, 16, 16, 512)  0          ['add_30[0][0]']
#  )
#
#  batch_normalization_88 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_115[0][0]']
#  ormalization)
#
#  concatenate_8 (Concatenate)    (None, 16, 16, 768)  0           ['up_sampling2d_17[0][0]',
#                                                                   'batch_normalization_88[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 16, 16, 256)  1769728     ['concatenate_8[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_116[0][0]']
#  ormalization)
#
#  activation_73 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_89[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 16, 16, 256)  590080      ['activation_73[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 16, 16, 256)  196864      ['concatenate_8[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_117[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_118[0][0]']
#  ormalization)
#
#  activation_74 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_90[0][0]']
#
#  add_32 (Add)                   (None, 16, 16, 256)  0           ['batch_normalization_91[0][0]',
#                                                                   'activation_74[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 16, 16, 128)  32896       ['add_32[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 16, 16, 128)  512        ['conv2d_119[0][0]']
#  ormalization)
#
#  activation_75 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_92[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 16, 16, 128)  16512       ['activation_75[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 16, 16, 128)  147584     ['conv2d_121[0][0]']
#  spose)
#
#  conv2d_120 (Conv2D)            (None, 16, 16, 128)  65664       ['add_28[0][0]']
#
#  add_33 (Add)                   (None, 16, 16, 128)  0           ['conv2d_transpose_9[0][0]',
#                                                                   'conv2d_120[0][0]']
#
#  activation_76 (Activation)     (None, 16, 16, 128)  0           ['add_33[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 16, 16, 1)    129         ['activation_76[0][0]']
#
#  activation_77 (Activation)     (None, 16, 16, 1)    0           ['conv2d_122[0][0]']
#
#  up_sampling2d_18 (UpSampling2D  (None, 32, 32, 1)   0           ['activation_77[0][0]']
#  )
#
#  lambda_9 (Lambda)              (None, 32, 32, 128)  0           ['up_sampling2d_18[0][0]']
#
#  multiply_9 (Multiply)          (None, 32, 32, 128)  0           ['lambda_9[0][0]',
#                                                                   'add_28[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 32, 32, 128)  16512       ['multiply_9[0][0]']
#
#  up_sampling2d_19 (UpSampling2D  (None, 32, 32, 256)  0          ['add_32[0][0]']
#  )
#
#  batch_normalization_93 (BatchN  (None, 32, 32, 128)  512        ['conv2d_123[0][0]']
#  ormalization)
#
#  concatenate_9 (Concatenate)    (None, 32, 32, 384)  0           ['up_sampling2d_19[0][0]',
#                                                                   'batch_normalization_93[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 32, 32, 128)  442496      ['concatenate_9[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 32, 32, 128)  512        ['conv2d_124[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_94[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 32, 32, 128)  147584      ['activation_78[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 32, 32, 128)  49280       ['concatenate_9[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 32, 32, 128)  512        ['conv2d_125[0][0]']
#  ormalization)
#
#  batch_normalization_96 (BatchN  (None, 32, 32, 128)  512        ['conv2d_126[0][0]']
#  ormalization)
#
#  activation_79 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_95[0][0]']
#
#  add_34 (Add)                   (None, 32, 32, 128)  0           ['batch_normalization_96[0][0]',
#                                                                   'activation_79[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 32, 32, 64)   8256        ['add_34[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 32, 32, 64)  256         ['conv2d_127[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_97[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 32, 32, 64)   4160        ['activation_80[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 32, 32, 64)  36928       ['conv2d_129[0][0]']
#  nspose)
#
#  conv2d_128 (Conv2D)            (None, 32, 32, 64)   16448       ['add_27[0][0]']
#
#  add_35 (Add)                   (None, 32, 32, 64)   0           ['conv2d_transpose_10[0][0]',
#                                                                   'conv2d_128[0][0]']
#
#  activation_81 (Activation)     (None, 32, 32, 64)   0           ['add_35[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 32, 32, 1)    65          ['activation_81[0][0]']
#
#  activation_82 (Activation)     (None, 32, 32, 1)    0           ['conv2d_130[0][0]']
#
#  up_sampling2d_20 (UpSampling2D  (None, 64, 64, 1)   0           ['activation_82[0][0]']
#  )
#
#  lambda_10 (Lambda)             (None, 64, 64, 64)   0           ['up_sampling2d_20[0][0]']
#
#  multiply_10 (Multiply)         (None, 64, 64, 64)   0           ['lambda_10[0][0]',
#                                                                   'add_27[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 64, 64, 64)   4160        ['multiply_10[0][0]']
#
#  up_sampling2d_21 (UpSampling2D  (None, 64, 64, 128)  0          ['add_34[0][0]']
#  )
#
#  batch_normalization_98 (BatchN  (None, 64, 64, 64)  256         ['conv2d_131[0][0]']
#  ormalization)
#
#  concatenate_10 (Concatenate)   (None, 64, 64, 192)  0           ['up_sampling2d_21[0][0]',
#                                                                   'batch_normalization_98[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 64, 64, 64)   110656      ['concatenate_10[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 64, 64, 64)  256         ['conv2d_132[0][0]']
#  ormalization)
#
#  activation_83 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_99[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 64, 64, 64)   36928       ['activation_83[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 64, 64, 64)   12352       ['concatenate_10[0][0]']
#
#  batch_normalization_100 (Batch  (None, 64, 64, 64)  256         ['conv2d_133[0][0]']
#  Normalization)
#
#  batch_normalization_101 (Batch  (None, 64, 64, 64)  256         ['conv2d_134[0][0]']
#  Normalization)
#
#  activation_84 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_100[0][0]']
#
#  add_36 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_101[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 64, 64, 32)   2080        ['add_36[0][0]']
#
#  batch_normalization_102 (Batch  (None, 64, 64, 32)  128         ['conv2d_135[0][0]']
#  Normalization)
#
#  activation_85 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_102[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 64, 64, 32)   1056        ['activation_85[0][0]']
#  conv2d_transpose_11 (Conv2DTra  (None, 64, 64, 32)  9248        ['conv2d_137[0][0]']
#  nspose)
#
#  conv2d_136 (Conv2D)            (None, 64, 64, 32)   4128        ['add_26[0][0]']
#
#  add_37 (Add)                   (None, 64, 64, 32)   0           ['conv2d_transpose_11[0][0]',
#                                                                   'conv2d_136[0][0]']
#
#  activation_86 (Activation)     (None, 64, 64, 32)   0           ['add_37[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 64, 64, 1)    33          ['activation_86[0][0]']
#
#  activation_87 (Activation)     (None, 64, 64, 1)    0           ['conv2d_138[0][0]']
#
#  up_sampling2d_22 (UpSampling2D  (None, 128, 128, 1)  0          ['activation_87[0][0]']
#  )
#
#  lambda_11 (Lambda)             (None, 128, 128, 32  0           ['up_sampling2d_22[0][0]']
#                                 )
#
#  multiply_11 (Multiply)         (None, 128, 128, 32  0           ['lambda_11[0][0]',
#                                 )                                 'add_26[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 128, 128, 32  1056        ['multiply_11[0][0]']
#                                 )
#
#  up_sampling2d_23 (UpSampling2D  (None, 128, 128, 64  0          ['add_36[0][0]']
#  )                              )
#
#  batch_normalization_103 (Batch  (None, 128, 128, 32  128        ['conv2d_139[0][0]']
#  Normalization)                 )
#
#  concatenate_11 (Concatenate)   (None, 128, 128, 96  0           ['up_sampling2d_23[0][0]',
#                                 )                                 'batch_normalization_103[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 128, 128, 32  27680       ['concatenate_11[0][0]']
#                                 )
#
#  batch_normalization_104 (Batch  (None, 128, 128, 32  128        ['conv2d_140[0][0]']
#  Normalization)                 )
#
#  activation_88 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_104[0][0]']
#                                 )
#
#  conv2d_141 (Conv2D)            (None, 128, 128, 32  9248        ['activation_88[0][0]']
#                                 )
#
#  conv2d_142 (Conv2D)            (None, 128, 128, 32  3104        ['concatenate_11[0][0]']
#                                 )
#
#  batch_normalization_105 (Batch  (None, 128, 128, 32  128        ['conv2d_141[0][0]']
#  Normalization)                 )
#
#  batch_normalization_106 (Batch  (None, 128, 128, 32  128        ['conv2d_142[0][0]']
#  Normalization)                 )
#
#  activation_89 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_105[0][0]']
#                                 )
#
#  add_38 (Add)                   (None, 128, 128, 32  0           ['batch_normalization_106[0][0]',
#                                 )                                 'activation_89[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 128, 128, 1)  33          ['add_38[0][0]']
#
#  batch_normalization_107 (Batch  (None, 128, 128, 1)  4          ['conv2d_143[0][0]']
#  Normalization)
#
#  attention_vec (Activation)     (None, 128, 128, 1)  0           ['batch_normalization_107[0][0]']
#
# ==================================================================================================
# Total params: 9,786,857
# Trainable params: 9,776,103
# Non-trainable params: 10,754
# __________________________________________________________________________________________________
#   0%|                                                                                           | 0/30 [00:00<?, ?it/s]
#  93%|████████████████████████████████████████████████████████████████████████████▌     | 28/30 [00:33<00:02,  1.32s/it]
# Gerbaux
# images:   0%|                                                                                  | 0/308 [00:00<?, ?it/s]
# images:  20%|██████████████▋                                                         | 63/308 [00:00<00:00, 628.93it/s]
# images:  53%|█████████████████████████████████████▊                                 | 164/308 [00:00<00:00, 852.39it/s]
# images: 100%|███████████████████████████████████████████████████████████████████████| 308/308 [00:00<00:00, 900.62it/s]
#  97%|███████████████████████████████████████████████████████████████████████████████▎  | 29/30 [00:33<00:01,  1.06s/it]
# Ghiles
# images:   0%|                                                                                  | 0/321 [00:00<?, ?it/s]
# images:  34%|███████████████████████▌                                              | 108/321 [00:00<00:00, 1074.40it/s]
# images:  67%|███████████████████████████████████████████████▊                       | 216/321 [00:00<00:00, 885.13it/s]
# images: 100%|███████████████████████████████████████████████████████████████████████| 321/321 [00:00<00:00, 809.18it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [00:34<00:00,  1.15s/it]
# (10798, 128, 128) (10798, 128, 128)
# (10135, 128, 128) (10135, 128, 128)
# Train set size :  7702
# Validation set size :  1926
# Total images :  10135
# (7702, 128, 128, 1)
# (1926, 128, 128, 1)
# Epoch 1/6
# 241/241 [==============================] - 2668s 11s/step - loss: 0.3154 - accuracy: 0.9109 - val_loss: 1.8569 - val_accuracy: 0.8796
# Epoch 2/6
# 241/241 [==============================] - 2506s 10s/step - loss: 0.1539 - accuracy: 0.9347 - val_loss: 1.0493 - val_accuracy: 0.8796
# Epoch 3/6
# 241/241 [==============================] - 2252s 9s/step - loss: 0.1250 - accuracy: 0.9470 - val_loss: 0.1287 - val_accuracy: 0.9413
# Epoch 4/6
# 241/241 [==============================] - 2215s 9s/step - loss: 0.1235 - accuracy: 0.9476 - val_loss: 0.1113 - val_accuracy: 0.9536
# Epoch 5/6
# 241/241 [==============================] - 2223s 9s/step - loss: 0.1068 - accuracy: 0.9551 - val_loss: 0.1444 - val_accuracy: 0.9473
# Epoch 6/6
# 241/241 [==============================] - 2216s 9s/step - loss: 0.1274 - accuracy: 0.9486 - val_loss: 0.1082 - val_accuracy: 0.9547

# %%
trainX1, evalX, trainY1, evalY = train_test_split(X, Y, test_size=0.05, shuffle=True)
trainX, valX, trainY, valY = train_test_split(trainX1, trainY1, test_size=0.2, shuffle=True)
print(trainX.shape)
print(valX.shape)
print(evalX.shape)
score = model.evaluate(valX, valY, verbose=1)
print("Loss: {:.2f}".format(score[0]*100))
print("Accuracy: {:.2f}".format(score[1]*100))
# history = model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=1, validation_data=(valX, valY),callbacks=callbacks_list)
evaluation_idxs = np.random.choice(valX.shape[0], 90, replace=False)
for i in range(evaluation_idxs.shape[0]):
    cv2.imwrite(os.path.join(output_path_single_class+evaluation_output, "PolyAttentionXevaluation_sample_stage_1_" + str(i) + ".jpeg"), valX[evaluation_idxs[i]]*255)
    cv2.imwrite(os.path.join(output_path_single_class+evaluation_output, "PolyAttentionYevaluation_sample_stage_1_" + str(i) + ".jpeg"), valY[evaluation_idxs[i]])
    cv2.imwrite(os.path.join(output_path_single_class+evaluation_output, "PolyAttentionPreprocessing_sample_stage_1_" + str(i) + ".jpeg")
                    , ((model.predict(np.expand_dims(valX[evaluation_idxs[i]], axis=0))*255).squeeze()))
showResults(history)
# Out:
# (8206, 128, 128)
# (2052, 128, 128)
# (540, 128, 128)
# 65/65 [==============================] - 151s 2s/step - loss: 448.4087 - accuracy: 0.6558
# Loss: 44840.87
# Accuracy: 65.58
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 108ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [51], in <cell line: 16>()
#      13     cv2.imwrite(os.path.join(output_path_single_class+evaluation_output, "PolyAttentionYevaluation_sample_stage_1_" + str(i) + ".jpeg"), valY[evaluation_idxs[i]])
#      14     cv2.imwrite(os.path.join(output_path_single_class+evaluation_output, "PolyAttentionPreprocessing_sample_stage_1_" + str(i) + ".jpeg")
#      15                     , ((model.predict(np.expand_dims(valX[evaluation_idxs[i]], axis=0))*255).squeeze()))
# ---> 16 showResults(history)
#
# NameError: name 'history' is not defined

# %%
model = load_model('model_single_classAttentionNet10_noAugmentation_fixed.hdf5')
outputs=[model.output, model.get_layer('activation_59').output]
model_outputs = outputs[0]
attention_outputs = outputs[1]

# %%
outputs
# Out:
# [<KerasTensor: shape=(None, 128, 128, 1) dtype=float32 (created by layer 'attention_vec')>,
#  <KerasTensor: shape=(None, 128, 128, 32) dtype=float32 (created by layer 'activation_59')>]

# %%
def postprocess_activations(attention_outputs):

  #using the approach in https://arxiv.org/abs/1612.03928
  output = np.abs(attention_outputs)
  output = np.sum(output, axis = -1).squeeze()

  #resize and convert to image 
  output = cv2.resize(output, (128, 128))
  output /= output.max()
  output *= 255
  return 255 - output.astype('uint8')

# %%
Lung_ima = X[600]

# %%
plt.imshow(Lung_ima)

# %%
res = model.predict(np.expand_dims(Lung_ima, axis = 0))*255
plt.imshow(res.squeeze())
# Out:
# 1/1 [==============================] - 1s 932ms/step

# %%
def preprocess(img):
  
  #expand the dimension
  return np.expand_dims(img, 0)

# %%
def apply_heatmap(weights, img):
  #generate heat maps 
  heatmap = cv2.applyColorMap(weights, cv2.COLORMAP_JET)
  heatmap = cv2.addWeighted(heatmap, 0.7, img, 0.3, 0)
  return heatmap

# %%
def plot_heatmaps(rng):
  level_maps = None
  
  #given a range of indices generate the heat maps 
  for i in rng:
    model = load_model('model_single_classAttentionNet10_noAugmentation_fixed.hdf5')
    outputs=[model.output, model.get_layer('activation_59').output]
    model_outputs = outputs[0]
    attention_outputs = outputs[1]
    model = tf.keras.models.Model(inputs = model.inputs, outputs = attention_outputs)

    out = model.predict(np.expand_dims(X[i*100], axis = 0)*255)
    print(i*100)
    weights = postprocess_activations(out)
    heatmap = apply_heatmap(weights, cv2.cvtColor(X[i*100],cv2.COLOR_GRAY2RGB))
    if level_maps is None:
      level_maps = heatmap
    else:
      level_maps = np.concatenate([level_maps, heatmap], axis = 1)
  plt.figure(figsize=(15, 15))
  plt.axis('off')
  ax = plt.imshow(level_maps)

# %%
plot_heatmaps(range(76, 81))
plot_heatmaps(range(3, 8))
# Out:
# 1/1 [==============================] - 1s 779ms/step
# 7600
# 1/1 [==============================] - 1s 766ms/step
# 7700
# 1/1 [==============================] - 1s 773ms/step
# 7800
# 1/1 [==============================] - 1s 776ms/step
# 7900
# 1/1 [==============================] - 1s 769ms/step
# 8000
# 1/1 [==============================] - 1s 876ms/step
# 300
# 1/1 [==============================] - 1s 850ms/step
# 400
# 1/1 [==============================] - 1s 772ms/step
# 500
# 1/1 [==============================] - 1s 927ms/step
# 600
# 1/1 [==============================] - 1s 808ms/step
# 700

# %%
# def train_single_class(batch_size=8, start=0, end=30, n_classes=1, img_rows=128, img_cols=128):
#     model = UNet3(img_rows=img_rows, img_cols=img_cols ,num_class=1, multiclass=False)
#     model.compile(optimizer=Adam(lr=1e-4), loss='binary_crossentropy', metrics=['accuracy']) 
#     model.summary()
#     X, Y = getPolygonDatarange(hdf5File,start,end,aug=True, rows=img_rows, cols=img_cols)

    
#     preprocessing_idxs = np.random.choice(X.shape[0], 9, replace=False)
#     for i in range(preprocessing_idxs.shape[0]):
#         cv2.imwrite(os.path.join(output_path_single_class+preprocessing_output, "Xpreprocessing_sample_stage_1_" + str(i) + ".jpeg"), X[preprocessing_idxs[i]])
#         cv2.imwrite(os.path.join(output_path_single_class+preprocessing_output, "Ypreprocessing_sample_stage_1_" + str(i) + ".jpeg"), Y[preprocessing_idxs[i]])   

#     trainX1, evalX, trainY1, evalY = train_test_split(X, Y, test_size=0.05, shuffle=True)
#     trainX, valX, trainY, valY = train_test_split(trainX1, trainY1, test_size=0.2, shuffle=True)

#     print("Train set size : ", len(trainX))
#     print("Validation set size : ", len(valX))
#     print("Total images : ", len(X))

#     trainX, trainY, valX, valY = prepareData(trainX, trainY, valX, valY)

#     csv_logger = CSVLogger('train'+str('')+'.log', append=True, separator=';')
#     earlystopping = EarlyStopping(monitor='accuracy', verbose=1, min_delta=0.005, patience=3, mode='max')
#     callbacks_list = [csv_logger, earlystopping]

#     history = model.fit(trainX, trainY, epochs=10, batch_size=batch_size, verbose=1, validation_data=(valX, valY),callbacks=callbacks_list)

#     model.save('model'+str('_single_class')+ str('UNet3') +'.hdf5')
#     score = model.evaluate(evalX, evalY, verbose=1)

#     print("Loss: {:.2f}".format(score[0]*100))
#     print("Accuracy: {:.2f}".format(score[1]*100))

#     evaluation_idxs = np.random.choice(valX.shape[0], 90, replace=False)
#     for i in range(evaluation_idxs.shape[0]):
#         cv2.imwrite(os.path.join(output_path_single_class+evaluation_output, "Xevaluation_sample_stage_1_" + str(i) + ".jpeg"), valX[evaluation_idxs[i]]*255)
#         cv2.imwrite(os.path.join(output_path_single_class+evaluation_output, "Yevaluation_sample_stage_1_" + str(i) + ".jpeg"), valY[evaluation_idxs[i]]*255)
#         cv2.imwrite(os.path.join(output_path_single_class+evaluation_output, "Ppreprocessing_sample_stage_1_" + str(i) + ".jpeg")
#                     , (model.predict(np.expand_dims(valX[evaluation_idxs[i]], axis=0)))*255)
   

#     showResults(history)
    
#     return model

# %%
# def train(batch_size=16, start=0, end=30, n_classes=1, img_rows=128, img_cols=128):
#     if n_classes == 1:
#         return train_single_class(batch_size=batch_size, start=start, end=end, n_classes=1, img_rows=img_rows, img_cols=img_cols)
#     else:
#         return train_multiclass(batch_size=batch_size, start=start, end=end, n_classes=n_classes, img_rows=img_rows, img_cols=img_cols)

# %%
# train()
